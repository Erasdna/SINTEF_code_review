# %% [markdown]
# Plots the BoxMesh generated by DolfinMesher in cideMOD

# %%
from dolfin import (
    DOLFIN_EPS,
    BoxMesh,
    CompiledSubDomain,
    Function,
    FunctionSpace,
    IntervalMesh,
    Measure,
    MeshFunction,
    Point,
    RectangleMesh,
    Timer,
    assemble,
    cells,
    plot, #Plotting
)

# %%
n=3 #dimension
p1 = Point(0,0,0)
p2 = Point(n,1,1)
Nx=5 #Spatial discretization
Ny=5
Nz=5

# %%
import matplotlib.pyplot as plt #to show plot
#BoxMesh
a=BoxMesh(p1,p2, Nx*n, Ny or Nx, Nz or Nx) #BoxMesh see Fenics
plot(a)
plt.show()
